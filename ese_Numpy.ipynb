# %% [markdown]
# # Esercitazione 25 Febbraio 2024

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Esercizio 1: Generazione di Sequenze e Operazioni Element-wise**
#
#     Genera un array NumPy arr1 di 20 numeri equidistanti tra 0 e 10 usando np.linspace().
#     Genera un array NumPy arr2 di 20 numeri casuali interi tra 1 e 5 usando np.random.randint().
#     Esegui un'operazione element-wise per creare un nuovo array arr3 dove ogni elemento è la somma di arr1 e arr2.
#     Calcola il quadrato di ogni elemento in arr3
#     Visualizza i risultati di arr1, arr2, arr3 e l'array risultante dal punto 4.

# %%
arr1 = np.linspace(0, 10, 20)
print(arr1)
# Out:
# [ 0.          0.52631579  1.05263158  1.57894737  2.10526316  2.63157895
#   3.15789474  3.68421053  4.21052632  4.73684211  5.26315789  5.78947368
#   6.31578947  6.84210526  7.36842105  7.89473684  8.42105263  8.94736842
#   9.47368421 10.        ]

# %%
arr2 = np. random.randint(1, 6, 20)
print(arr2)
# Out:
# [3 2 1 1 5 1 1 2 4 5 4 4 4 4 1 4 2 2 5 2]

# %%
sum = arr1 + arr2 
print(sum)
# Out:
# [ 3.          2.52631579  2.05263158  2.57894737  7.10526316  3.63157895
#   4.15789474  5.68421053  8.21052632  9.73684211  9.26315789  9.78947368
#  10.31578947 10.84210526  8.36842105 11.89473684 10.42105263 10.94736842
#  14.47368421 12.        ]

# %%
sq = sum * sum
print(sq)
# Out:
# [  9.           6.38227147   4.2132964    6.65096953  50.48476454
#   13.18836565  17.28808864  32.31024931  67.41274238  94.80609418
#   85.80609418  95.83379501 106.41551247 117.55124654  70.03047091
#  141.48476454 108.59833795 119.84487535 209.48753463 144.        ]

# %% [markdown]
# **Esercizio 2 : Valutazione e Visualizzazione di una Funzione**
#
#     Definisci la funzione matematica f(x) = sin(x^2) / (x^2 + 1) nell'intervallo [-5, 5]  usando una lambda function.
#     Genera un array NumPy x contenente 110 punti equidistanti in un intervallo a tua scelta (ad esempio, tra -10 e 10).
#     Valuta la funzione definita al punto 1 in ciascun punto dell'array x, creando un array y contenente i valori della funzione.
#     Utilizza Matplotlib per creare un grafico della funzione, con x sull'asse orizzontale e y sull'asse verticale.
#     Aggiungi un titolo al grafico, etichette agli assi e una griglia per una migliore visualizzazione.

# %%
f1 = lambda x: np.sin(x**2) / (x**2 + 1)

# %%
x = np.linspace(-10, 10- 110)
print(x)
# Out:
# [ -10.          -11.83673469  -13.67346939  -15.51020408  -17.34693878
#   -19.18367347  -21.02040816  -22.85714286  -24.69387755  -26.53061224
#   -28.36734694  -30.20408163  -32.04081633  -33.87755102  -35.71428571
#   -37.55102041  -39.3877551   -41.2244898   -43.06122449  -44.89795918
#   -46.73469388  -48.57142857  -50.40816327  -52.24489796  -54.08163265
#   -55.91836735  -57.75510204  -59.59183673  -61.42857143  -63.26530612
#   -65.10204082  -66.93877551  -68.7755102   -70.6122449   -72.44897959
#   -74.28571429  -76.12244898  -77.95918367  -79.79591837  -81.63265306
#   -83.46938776  -85.30612245  -87.14285714  -88.97959184  -90.81632653
#   -92.65306122  -94.48979592  -96.32653061  -98.16326531 -100.        ]

# %%
y = f1(x)
print(y)
# Out:
# [-5.01352120e-03  6.75452120e-03 -5.31612840e-03  4.02625938e-03
#  -2.07393032e-03 -1.17136906e-03  2.01952705e-03  1.54792936e-03
#   5.12862978e-04  2.21305017e-04  5.49506322e-04  1.03001250e-03
#   6.17092755e-04 -7.35891180e-04  1.84757922e-05  3.37247588e-04
#  -3.37530999e-04  8.38474464e-05  3.59200820e-04 -4.36301339e-04
#  -3.03379450e-04  6.43255099e-05  2.10806248e-04  1.80270175e-04
#  -7.85859430e-08 -2.65358381e-04 -1.97525448e-04  2.61068651e-04
#  -1.07210691e-04  2.74002542e-05 -6.22888416e-05  1.73179034e-04
#  -1.94430308e-04 -7.46718121e-05  1.29376150e-04  1.78870324e-04
#   1.72403012e-04  1.60425046e-04  9.12016980e-05 -8.12223354e-05
#  -1.13637015e-04  1.28353714e-04 -7.94849642e-05  6.64692747e-05
#  -9.67786577e-05  1.14425693e-04 -9.48417532e-06 -1.07149273e-04
#  -7.16362378e-05 -3.05583831e-05]

# %%
plt.plot(x, y)
plt.grid(True)
plt.title("F: sin(x^2) / (x^2 +1)")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **Esercizio 3: Reshape e Funzioni Universali**
#
#     Genera un array NumPy arr di 36 numeri casuali in virgola mobile tra 0 e 1 usando np.random.rand().
#     Rimodella arr in una matrice 6x6 usando arr.reshape().
#     Calcola il seno di ogni elemento nella matrice usando np.sin().
#     Calcola la media di ogni riga della matrice risultante usando np.mean() con l'asse appropriato.
#     Visualizza la matrice rimodellata, la matrice del seno e le medie delle righe.

# %%
arr = np.random.rand(36)
print(arr)
# Out:
# [0.02649019 0.10587329 0.98879528 0.61892941 0.37864179 0.16164857
#  0.1169653  0.84355926 0.36573377 0.45867915 0.32644938 0.19997916
#  0.23395775 0.98189804 0.1734298  0.26362669 0.71617212 0.5183963
#  0.22576143 0.76245825 0.83140003 0.77377156 0.92925925 0.24720849
#  0.7245522  0.91770531 0.5087766  0.80777621 0.63894752 0.07575825
#  0.35740193 0.47236717 0.4707108  0.46128415 0.99393059 0.18728889]

# %%
arr = arr.reshape((6,6))
print(arr)
# Out:
# [[0.02649019 0.10587329 0.98879528 0.61892941 0.37864179 0.16164857]
#  [0.1169653  0.84355926 0.36573377 0.45867915 0.32644938 0.19997916]
#  [0.23395775 0.98189804 0.1734298  0.26362669 0.71617212 0.5183963 ]
#  [0.22576143 0.76245825 0.83140003 0.77377156 0.92925925 0.24720849]
#  [0.7245522  0.91770531 0.5087766  0.80777621 0.63894752 0.07575825]
#  [0.35740193 0.47236717 0.4707108  0.46128415 0.99393059 0.18728889]]

# %%
sen = np.sin(arr)
print(sen)
# Out:
# [[0.02648709 0.10567561 0.83536435 0.5801635  0.3696588  0.1609455 ]
#  [0.11669878 0.74701407 0.35763463 0.44276417 0.32068196 0.1986489 ]
#  [0.23182926 0.83155312 0.17256171 0.26058365 0.65650202 0.49548778]
#  [0.22384854 0.69070119 0.73887549 0.69883792 0.80117688 0.24469827]
#  [0.6628002  0.79420936 0.48710916 0.72275209 0.59635092 0.0756858 ]
#  [0.34984152 0.4549955  0.45351989 0.4450984  0.83817619 0.18619588]]

# %%
mean = np.mean(arr, axis =1)
print (mean)
# Out:
# [0.38006309 0.38522767 0.48124678 0.62830984 0.61225268 0.49049725]

# %% [markdown]
# **Esercizio 4: Campionamento Casuale e Operazioni Logiche**
#
#     Genera un array NumPy arr di 100 numeri casuali interi tra -10 e 10 usando np.random.randint().
#     Crea una maschera booleana che seleziona gli elementi di arr che sono maggiori di 5 o minori di -5.
#     Usa la maschera per creare un nuovo array arr_filtered contenente solo gli elementi selezionati.
#     Calcola il valore assoluto di ogni elemento in arr_filtered usando np.abs().
#     Visualizza arr, la maschera booleana, arr_filtered e l'array dei valori assoluti.

# %%
arr = np.random.randint(-10, 11, 100)
print(arr)
# Out:
# [ -7  -8  -2  10  -3   0  -7  -5  -1   9  -2  -8  -5   1  -6  -9   6  -7
#    7   8 -10 -10 -10  -5   1  -7  -1   5  -2   7   6  -6   4  -9  -2   7
#    5   8  -6   1   7  -1   9 -10  -7   4   0   4   8   1   4   8  -2 -10
#   -5   0  -1  10   5  -9   6   2  -9   6  -1   8  -1  -7   9 -10  -5   6
#    5 -10   9   3  -4 -10  -1   3   5  10  -4 -10  -3  -7  -9  -9  -1  -3
#   -1 -10   6  10  -6  -7   1   6   4   2]

# %%
mask = arr > -5
print(mask)
# Out:
# [False False  True  True  True  True False False  True  True  True False
#  False  True False False  True False  True  True False False False False
#   True False  True  True  True  True  True False  True False  True  True
#   True  True False  True  True  True  True False False  True  True  True
#   True  True  True  True  True False False  True  True  True  True False
#   True  True False  True  True  True  True False  True False False  True
#   True False  True  True  True False  True  True  True  True  True False
#   True False False False  True  True  True False  True  True False False
#   True  True  True  True]

# %%
arr_filtered = arr[mask]
print(arr_filtered)
# Out:
# [-2 10 -3  0 -1  9 -2  1  6  7  8  1 -1  5 -2  7  6  4 -2  7  5  8  1  7
#  -1  9  4  0  4  8  1  4  8 -2  0 -1 10  5  6  2  6 -1  8 -1  9  6  5  9
#   3 -4 -1  3  5 10 -4 -3 -1 -3 -1  6 10  1  6  4  2]

# %%
abs = np.abs(arr_filtered)
print(abs)
# Out:
# [ 2 10  3  0  1  9  2  1  6  7  8  1  1  5  2  7  6  4  2  7  5  8  1  7
#   1  9  4  0  4  8  1  4  8  2  0  1 10  5  6  2  6  1  8  1  9  6  5  9
#   3  4  1  3  5 10  4  3  1  3  1  6 10  1  6  4  2]

# %% [markdown]
# **Esercizio 5: Generazione di Griglie e Operazioni Element-wise Complesse**
#
#     Crea due array NumPy x e y di 10 numeri equidistanti tra 1 e 5 usando np.linspace().
#     Crea una matrice xx ripetendo x lungo le righe e una matrice yy ripetendo y lungo le colonne.
#     Calcola z = sin(xx^2 + yy^2) / (xx^2 + yy^2) element-wise, dove xx e yy sono le matrici generate. Usa np.sin(), np.square(), e operazioni di divisione.
#     Visualizza le matrici xx, yy e z.e griglie x, y e la matrice z.

# %% [markdown]
# **Esercizio 6: Campionamento da Distribuzioni e Statistiche**
#
#     Genera un array NumPy arr di 1000 numeri casuali campionati da una distribuzione normale con media 0 e deviazione standard 1 usando np.random.randn().
#     Rimodella arr in una matrice 100x10.
#     Calcola la media di ogni riga della matrice usando np.mean() con l'asse appropriato.
#     Visualizza l'array originale, la matrice rimodellata, le medie delle righe.
